# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pc = pd.read_excel("uso pc italia.xlsx")

# %%
dati2020 = pc.iloc[4:18,:]
dati2020 = dati2020.dropna(how='all', axis=1)
dati2020
# Out:
#    Misura     Unnamed: 1  Unnamed: 4  Unnamed: 6  Unnamed: 8  Unnamed: 10  \
# 4    2020       3-5 anni        17.8         4.5         9.0          1.7
# 5     NaN      6-10 anni        62.4        21.4        32.9          5.6
# 6     NaN     11-14 anni        83.0        42.1        35.0          3.9
# 7     NaN     15-17 anni        83.4        47.2        30.5          4.6
# 8     NaN     18-19 anni        81.9        44.9        28.4          5.8
# 9     NaN     20-24 anni        78.9        47.4        24.9          4.3
# 10    NaN     25-34 anni        72.9        44.9        22.0          3.7
# 11    NaN     35-44 anni        69.8        44.1        18.7          4.4
# 12    NaN     45-54 anni        64.6        41.4        16.9          4.0
# 13    NaN     55-59 anni        57.1        36.8        15.4          2.4
# 14    NaN     60-64 anni        51.3        31.9        14.5          3.1
# 15    NaN     65-74 anni        31.6        17.1        11.0          2.3
# ...

# %%
dati2021 = pc.iloc[18:33,:]
dati2021 = dati2021.dropna(how='all', axis=1)
dati2021
# Out:
#    Misura     Unnamed: 1  Unnamed: 4  Unnamed: 6  Unnamed: 8  Unnamed: 10  \
# 18   2021       3-5 anni        23.4         5.4        13.4          1.9
# 19    NaN      6-10 anni        72.3        31.7        34.1          4.4
# 20    NaN     11-14 anni        83.9        56.9        24.2          2.4
# 21    NaN     15-17 anni        83.1        66.8        14.8          0.8
# 22    NaN     18-19 anni        83.4        63.0        17.7          1.7
# 23    NaN     20-24 anni        77.4        55.5        17.5          3.1
# 24    NaN     25-34 anni        73.6        47.3        19.8          4.1
# 25    NaN     35-44 anni        69.7        44.4        19.4          3.7
# 26    NaN     45-54 anni        67.1        45.0        15.7          3.8
# 27    NaN     55-59 anni        60.8        40.2        15.1          2.9
# 28    NaN     60-64 anni        54.4        34.2        14.7          3.4
# 29    NaN     65-74 anni        36.4        21.0        11.2          2.4
# ...

# %%
ages = ["3-5","6-10","11-14","15-17","18-19","20-24","25-34","35-44","45-54","55-59","60-64","65-74","75 o più"]
list1 = dati2020['Unnamed: 4'].to_numpy()
list2 = dati2021['Unnamed: 4'].to_numpy()
list = {'2020':list1[:13], '2021': list2[:13]}
df = pd.DataFrame(list, index=ages)



df.plot.bar(rot = 0, figsize=(15,11))
plt.xticks(fontsize=16) 
plt.yticks(fontsize=16) 
ax = plt.gca()
ax.yaxis.grid(True)
plt.xlabel("anni" , fontsize=15)
plt.savefig('pc_use_italy_by_age.jpg', dpi=300, bbox_inches='tight')
plt.show()
