# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 

internet = pd.read_excel("../dati/internet use around the globe.xlsx")
internet
# Out:
#     Key ICT indicators for developed and developing countries, the world and special regions (totals and penetration rates)  \
# 0                                                  NaN
# 1                        Fixed-telephone subscriptions
# 2                                                  NaN
# 3                                                World
# 4                                            Developed
# ..                                                 ...
# 99                                                 NaN
# 100                                            Source:
# 101  ITU World Telecommunication/ICT Indicators dat...
# 102                                                NaN
# 103  Updated: 25 January 2022 (revised series for I...
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1     Millions         NaN         NaN         NaN         NaN         NaN
# ...

# %%
years = internet.iloc[[83],1:18].to_numpy()[0]
values = internet.iloc[[84],1:18].to_numpy()[0]
years = years.astype(int)

# %%
plt.figure(figsize=(16,10),)
plt.plot(years,values, marker="o" , linewidth=5, markersize=20)
plt.grid(True)
plt.xticks(fontsize=14) 
plt.yticks(fontsize=14) 
plt.savefig('internet_users_over_time.jpg', dpi=300, bbox_inches='tight')
plt.show()
